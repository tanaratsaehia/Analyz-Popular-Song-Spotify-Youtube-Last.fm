# %%
import pandas as pd
import numpy as np

# %%
data_youtube = pd.read_csv('/content/youtube_song_data.csv')
data_spotify = pd.read_csv('/content/spotify.csv')
data_last_fm = pd.read_csv("/content/Last_fm_base_on_spotify.csv")

# %% [markdown]
# # Data Understanding and Cleaning (Youtube)

# %%
df = data_youtube.copy()

# %%
df.head(5)
# Out:
#                     song_name     video_id  \
# 0     Shape of You Ed Sheeran  liTfD88dbCo
# 1  Blinding Lights The Weeknd  XwxLwG2_Sxk
# 2    Dance Monkey Tones and I  q0hyYWKXF0Q
# 3           When I'm With You  qiaLTtDLB10
# 4     Moonlit Floor (Kiss Me)  pxGM_TOgHuM
#
#                                                title          artist  \
# 0                 Ed Sheeran - Shape of You (Lyrics)         7clouds
# 1              The Weeknd - Blinding Lights (Lyrics)         7clouds
# 2        TONES AND I - DANCE MONKEY (OFFICIAL VIDEO)     Tones And I
# 3  NCT DREAM 엔시티 드림 &#39;When I&#39;m With You&#3...       NCT DREAM
# 4  LISA - MOONLIT FLOOR (Official Performance Video)  LLOUD Official
#
#            release_date         views       likes  comments error
# 0  2024-12-13T19:33:36Z  1.617114e+07     87989.0    3379.0   NaN
# 1  2020-03-01T18:09:07Z  1.424817e+08   1369380.0   35208.0   NaN
# 2  2019-06-24T22:01:36Z  2.212981e+09  16058425.0  392347.0   NaN
# 3  2024-11-18T15:00:59Z  1.356990e+06     76411.0    2642.0   NaN
# 4  2024-10-09T00:00:07Z  6.620069e+07   1310509.0   46314.0   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7220 entries, 0 to 7219
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   song_name     7220 non-null   object
#  1   video_id      7206 non-null   object
#  2   title         7206 non-null   object
#  3   artist        7206 non-null   object
#  4   release_date  7206 non-null   object
#  5   views         7205 non-null   float64
#  6   likes         7178 non-null   float64
#  7   comments      7165 non-null   float64
#  8   error         14 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 507.8+ KB

# %%
df[df['error'].notnull()]
# Out:
#                        song_name video_id title artist release_date  views  \
# 99                     New Jeans      NaN   NaN    NaN          NaN    NaN
# 1794                     FRIENDS      NaN   NaN    NaN          NaN    NaN
# 2408              After Midnight      NaN   NaN    NaN          NaN    NaN
# 2437                     Charmed      NaN   NaN    NaN          NaN    NaN
# 2499                      Advice      NaN   NaN    NaN          NaN    NaN
# 2776  Fiebre (Prod. King DouDou)      NaN   NaN    NaN          NaN    NaN
# 2867                     BADGYAL      NaN   NaN    NaN          NaN    NaN
# 3069                     Run BTS      NaN   NaN    NaN          NaN    NaN
# 3310                  Stray Kids      NaN   NaN    NaN          NaN    NaN
# 4323                     Friends      NaN   NaN    NaN          NaN    NaN
# 4478                    Treasure      NaN   NaN    NaN          NaN    NaN
# 6002                    No Cigar      NaN   NaN    NaN          NaN    NaN
# 6146                Kiss of Life      NaN   NaN    NaN          NaN    NaN
# 7011                Imagineering      NaN   NaN    NaN          NaN    NaN
#
#       likes  comments                                           error
# 99      NaN       NaN                     Unexpected error: 'videoId'
# 1794    NaN       NaN                     Unexpected error: 'videoId'
# 2408    NaN       NaN                     Unexpected error: 'videoId'
# 2437    NaN       NaN                     Unexpected error: 'videoId'
# 2499    NaN       NaN                     Unexpected error: 'videoId'
# 2776    NaN       NaN  Unexpected error: The read operation timed out
# 2867    NaN       NaN                     Unexpected error: 'videoId'
# 3069    NaN       NaN                     Unexpected error: 'videoId'
# 3310    NaN       NaN                     Unexpected error: 'videoId'
# 4323    NaN       NaN                     Unexpected error: 'videoId'
# 4478    NaN       NaN                     Unexpected error: 'videoId'
# 6002    NaN       NaN                     Unexpected error: 'videoId'
# 6146    NaN       NaN                     Unexpected error: 'videoId'
# 7011    NaN       NaN                     Unexpected error: 'videoId'

# %%
new_df  = df[df['error'].isna()].drop('error', axis=1)

# %%
new_df.sample(5)
# Out:
#                             song_name     video_id  \
# 3386         Everybody Loves Somebody  z-2_OstpR5c
# 3113  UNFORGIVEN (feat. Nile Rodgers)  UBURTj20HXI
# 704                        I Got Love  nidQCt_HEsY
# 4225                     Tell Me Baby  oDNcL1VP3rY
# 773                         na Circus  Y7FvDGluRS4
#
#                                                   title  \
# 3386  Dean Martin - Everybody Loves Somebody (Offici...
# 3113  LE SSERAFIM (르세라핌) &#39;UNFORGIVEN (feat. Nile...
# 704   Miyagi &amp; Эндшпиль feat. Рем Дигга - I Got ...
# 4225  Red Hot Chili Peppers - Tell Me Baby [Official...
# 773                                           na Circus
#
#                             artist          release_date         views  \
# 3386                DeanMartinVEVO  2017-05-25T07:00:02Z  2.852018e+07
# 3113                   HYBE LABELS  2023-05-01T08:58:10Z  1.349732e+08
# 704                         Hajime  2017-06-02T11:30:01Z  1.025395e+09
# 4225         Red Hot Chili Peppers  2011-07-19T22:11:56Z  9.023184e+07
# 773   FRIENDLY THUG 52 NGG - Topic  2023-11-02T21:02:42Z  7.320195e+06
#
#           likes  comments
# 3386   512994.0   10263.0
# 3113  2015353.0   70614.0
# 704   3968509.0  220194.0
# 4225   357296.0   11176.0
# 773     47902.0     258.0

# %%
new_df.isnull().sum()
# Out:
# song_name        0
# video_id         0
# title            0
# artist           0
# release_date     0
# views            1
# likes           28
# comments        41
# dtype: int64

# %%
new_df[new_df['views'].isnull()]
# Out:
#      song_name     video_id                               title  \
# 1249       One  ED1ObmER_SQ  ONE 170: Tawanchai vs. Superbon II
#
#                 artist          release_date  views  likes  comments
# 1249  ONE Championship  2025-01-24T16:47:06Z    NaN    NaN       NaN

# %%
song_na_likes = [new_df.loc[i,'song_name'] for i in new_df[new_df['likes'].isnull()].index]

# %%
song_na_comments = [new_df.loc[i,'song_name'] for i in new_df[new_df['comments'].isnull()].index]

# %%
for i in song_na_likes:
  if i in song_na_comments:
    print(i)
  else:
    continue
# Out:
# One
# 忘れられないの
# 新宝島
# Panorama
# Medication
# Hungarian Dance No. 5 in G Minor, WoO 1, No. 5
# Hungarian Dance No. 5
# Water Under the Bridge
# Blackwater - 128 full strings vocal mix

# %%
new_df.drop(new_df[new_df['views'].isnull()].index, inplace=True)
new_df.drop(new_df[new_df['likes'].isnull()].index, inplace=True)

# %%
new_df.isnull().sum()
# Out:
# song_name        0
# video_id         0
# title            0
# artist           0
# release_date     0
# views            0
# likes            0
# comments        32
# dtype: int64

# %%
new_df.drop('comments', axis=1, inplace=True)

# %%
new_df.isnull().sum()
# Out:
# song_name       0
# video_id        0
# title           0
# artist          0
# release_date    0
# views           0
# likes           0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7178 entries, 0 to 7219
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   song_name     7178 non-null   object
#  1   video_id      7178 non-null   object
#  2   title         7178 non-null   object
#  3   artist        7178 non-null   object
#  4   release_date  7178 non-null   object
#  5   views         7178 non-null   float64
#  6   likes         7178 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 448.6+ KB

# %%
new_df.duplicated().sum()
# Out:
# 0

# %%
new_df.to_csv('cleaned_data_yt.csv', index=False)

# %% [markdown]
# # Data Understanding and Cleaning (Spotify)

# %%
new_df = data_spotify.copy()
new_df.head(5)
# Out:
#                        id                 track_name                 artist  \
# 0  15cQVPbbwv0sZXrHRIAZeX          When I'm With You              NCT DREAM
# 1  3yDRcs0Y4pPzkvMbUfeF9H    Moonlit Floor (Kiss Me)                   LISA
# 2  7tI8dRuH2Yc6RuoTjxo4dU                        Who                  Jimin
# 3  7ov3TDp5D00Rnu5R1viX4w  New Woman (feat. ROSALÍA)          LISA, ROSALÍA
# 4  2plbrEY59IikOBgBGLjaoe           Die With A Smile  Lady Gaga, Bruno Mars
#
#                        album  popularity release_date  \
# 0                 DREAMSCAPE          74   2024-11-11
# 1    Moonlit Floor (Kiss Me)          79   2024-10-03
# 2                       MUSE          86   2024-07-19
# 3  New Woman (feat. ROSALÍA)          77   2024-08-15
# 4           Die With A Smile          97   2024-08-16
#
#                                          spotify_url  preview_url Genre
# 0  https://open.spotify.com/track/15cQVPbbwv0sZXr...          NaN   pop
# 1  https://open.spotify.com/track/3yDRcs0Y4pPzkvM...          NaN   pop
# 2  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...          NaN   pop
# 3  https://open.spotify.com/track/7ov3TDp5D00Rnu5...          NaN   pop
# 4  https://open.spotify.com/track/2plbrEY59IikOBg...          NaN   pop

# %%
new_df = new_df.drop('preview_url', axis=1)

# %%
new_df[new_df['album'].isna()]
# Out:
#                           id track_name  artist album  popularity  \
# 3079  0V2passWyAXnON67kfAj7y       ABCD  NAYEON   NaN          68
#
#      release_date                                        spotify_url  Genre
# 3079   2024-06-14  https://open.spotify.com/track/0V2passWyAXnON6...  k-pop

# %%
new_df.loc[3079,'album'] = 'NA'

# %%
new_df.isnull().sum()
# Out:
# id                 0
# track_name         0
# artist             0
# album              0
# popularity         0
# release_date       0
# spotify_url        0
# preview_url     7217
# Genre              0
# dtype: int64

# %%
# Not run
years = []
months = []
days = []
for i in new_df.index:
  release_date = new_df.loc[i,'release_date']
  temp = release_date.split('-')
  if len(release_date) == 4:
    years.append(temp[0])
    months.append(np.NaN)
    days.append(np.NaN)
  elif len(release_date) == 7:
    years.append(temp[0])
    months.append(temp[1])
    days.append(np.NaN)
  else:
    years.append(temp[0])
    months.append(temp[1])
    days.append(temp[2])
new_df['year'] = years
new_df['month'] = months
new_df['day'] = days

# %%
new_df
# Out:
#                           id                         track_name  \
# 0     15cQVPbbwv0sZXrHRIAZeX                  When I'm With You
# 1     3yDRcs0Y4pPzkvMbUfeF9H            Moonlit Floor (Kiss Me)
# 2     7tI8dRuH2Yc6RuoTjxo4dU                                Who
# 3     7ov3TDp5D00Rnu5R1viX4w          New Woman (feat. ROSALÍA)
# 4     2plbrEY59IikOBgBGLjaoe                   Die With A Smile
# ...                      ...                                ...
# 7212  70k5BJcKCA6raiC345tdSb  How To Save A Life - Techno Remix
# 7213  2T6DsaUYxwYeIyYTwD68ol                              裸足の季節
# 7214  0KCT63T5YEsW8pNnuhr9ZC                   Light Up the Sky
# 7215  7oAM2GxHCTKTLU3gXvkuuj                    Die Welt Brennt
# 7216  40hscplKySBPzeXEhfBy7E  Body Language - Original Remaster
#
#                          artist                              album  \
# 0                     NCT DREAM                         DREAMSCAPE
# 1                          LISA            Moonlit Floor (Kiss Me)
# 2                         Jimin                               MUSE
# 3                 LISA, ROSALÍA          New Woman (feat. ROSALÍA)
# 4         Lady Gaga, Bruno Mars                   Die With A Smile
# ...                         ...                                ...
# 7212                  Discotekk  How To Save A Life (Techno Remix)
# 7213              Seiko Matsuda                              BIBLE
# 7214                The Prodigy                        No Tourists
# 7215  Klangkuenstler, Obernauer                    Die Welt Brennt
# 7216    M.A.N.D.Y., Booka Shade                      Body Language
#
#       popularity release_date  \
# 0             74   2024-11-11
# 1             79   2024-10-03
# 2             86   2024-07-19
# 3             77   2024-08-15
# 4             97   2024-08-16
# ...          ...          ...
# 7212          55   2023-09-15
# 7213          33         1980
# 7214          43   2018-11-02
# 7215          48   2023-02-03
# 7216          42   2023-03-31
#
#                                             spotify_url   Genre
# 0     https://open.spotify.com/track/15cQVPbbwv0sZXr...     pop
# 1     https://open.spotify.com/track/3yDRcs0Y4pPzkvM...     pop
# 2     https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...     pop
# 3     https://open.spotify.com/track/7ov3TDp5D00Rnu5...     pop
# 4     https://open.spotify.com/track/2plbrEY59IikOBg...     pop
# ...                                                 ...     ...
# 7212  https://open.spotify.com/track/70k5BJcKCA6raiC...  techno
# 7213  https://open.spotify.com/track/2T6DsaUYxwYeIyY...  techno
# 7214  https://open.spotify.com/track/0KCT63T5YEsW8pN...  techno
# 7215  https://open.spotify.com/track/7oAM2GxHCTKTLU3...  techno
# 7216  https://open.spotify.com/track/40hscplKySBPzeX...  techno
#
# [7217 rows x 8 columns]

# %%
new_df.to_csv('cleaned_data_spotify.csv', index=False)

# %%
count_ymd = 0
count_ym = 0
count_y = 0
for i in new_df.index:
  release_date = new_df.loc[i,'release_date']
  if len(release_date) == 4:
    count_y += 1
  elif len(release_date) == 7:
    count_ym += 1
  else:
    count_ymd += 1
print('-'*30)
print(count_y,':',count_ym,':',count_ymd)
# Out:
# ------------------------------
# 441 : 19 : 6757

# %% [markdown]
# # Data Understanding and Cleaning (Last fm)

# %%
data = data_last_fm.copy()

# %%
data.head(5)
# Out:
#                        Track                 Artist  Listeners  Playcount  \
# 0          When I'm With You              NCT DREAM      41296     660264
# 1    Moonlit Floor (Kiss Me)                   LISA     164108    2545493
# 2                        Who                  Jimin     290397  118664117
# 3  New Woman (feat. ROSALÍA)          LISA, ROSALÍA      13329     573805
# 4           Die With A Smile  Lady Gaga, Bruno Mars      35802     562233
#
#                      Album                                               Tags  \
# 0                      NaN  ['House', 'Awesome', 'upbeat', 'Korean', 'k-pop']
# 1  Moonlit Floor (Kiss Me)  ['pop', 'dance pop', 'nu-disco', 'Hip-Hop', 'r...
# 2                      NaN     ['homosexual', 'soty', 'bots', 'who', 'jimin']
# 3                      NaN                                                 []
# 4                      NaN              ['collab', 'primadonna', 'lady mars']
#
#                                                  URL
# 0  https://www.last.fm/music/NCT+DREAM/_/When+I%2...
# 1  https://www.last.fm/music/Lisa/_/Moonlit+Floor...
# 2              https://www.last.fm/music/jimin/_/Who
# 3  https://www.last.fm/music/LISA,+ROSAL%C3%8DA/_...
# 4  https://www.last.fm/music/Lady+Gaga,+Bruno+Mar...

# %%
data = data[['Track', 'Artist', 'Listeners', 'Playcount']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7211 entries, 0 to 7210
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Track      7211 non-null   object
#  1   Artist     7211 non-null   object
#  2   Listeners  7211 non-null   int64
#  3   Playcount  7211 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 225.5+ KB

# %%
data.to_csv('cleaned_data_last_fm.csv', index=False)

# %% [markdown]
# # merge dataframe

# %%
spotify = pd.read_csv('/content/cleaned_data_spotify.csv')
youtube = pd.read_csv('/content/cleaned_data_yt.csv')
last_fm = pd.read_csv('/content/cleaned_data_last_fm.csv')

# %%
spotify.columns
# Out:
# Index(['id', 'track_name', 'artist', 'album', 'popularity', 'release_date',
#        'spotify_url', 'Genre'],
#       dtype='object')

# %%
youtube.columns
# Out:
# Index(['song_name', 'video_id', 'title', 'artist', 'release_date', 'views',
#        'likes'],
#       dtype='object')

# %%
last_fm.columns
# Out:
# Index(['Track', 'Artist', 'Listeners', 'Playcount'], dtype='object')

# %%
df_fm = last_fm.copy()
df_sp = spotify.copy()
df_yt = youtube.copy()

df_fm.rename(columns={'Track': 'track_name'}, inplace=True)
df_yt.rename(columns={'song_name': 'track_name'}, inplace=True)
df_sp.rename(columns={'track_name': 'track_name'}, inplace=True)

#select column
df_yt = df_yt[['track_name', 'views', 'likes']]
df_sp = df_sp[['track_name', 'popularity', 'artist', 'album', 'release_date']]
df_fm = df_fm[['track_name', 'Listeners', 'Playcount']]

# merg_spo_yt = df_sp.merge(df_yt, on=['track_name', 'artist'], how='left')
merged_left = pd.merge(df_fm, df_sp, on='track_name', how='left')

# %%
merged_left.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7211 entries, 0 to 7210
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_name    7211 non-null   object
#  1   Listeners     7211 non-null   int64
#  2   Playcount     7211 non-null   int64
#  3   popularity    7211 non-null   int64
#  4   artist        7211 non-null   object
#  5   album         7210 non-null   object
#  6   release_date  7211 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 394.5+ KB

# %%
merged_left[merged_left['album'].isnull()]
# Out:
#      track_name  Listeners  Playcount  popularity  artist album release_date
# 3079       ABCD     243727    5147537          68  NAYEON   NaN   2024-06-14

# %%
merged_left.loc[3079,'album'] = 'NA'

# %%
merged_final = pd.merge(merged_left, df_yt, on='track_name', how='left')

# %%
merged_cleaned = merged_final.dropna(subset=['views', 'likes'])

# %%
merged_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7169 entries, 0 to 7210
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_name    7169 non-null   object
#  1   Listeners     7169 non-null   int64
#  2   Playcount     7169 non-null   int64
#  3   popularity    7169 non-null   int64
#  4   artist        7169 non-null   object
#  5   album         7169 non-null   object
#  6   release_date  7169 non-null   object
#  7   views         7169 non-null   float64
#  8   likes         7169 non-null   float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 560.1+ KB

# %%
for i in merged_cleaned.index:
  release_date = merged_cleaned.loc[i,'release_date']
  temp = release_date.split('-')
  if len(release_date) == 4:
    merged_cleaned.loc[i,'year'] = temp[0]
    merged_cleaned.loc[i,'month'] = np.NaN
    merged_cleaned.loc[i,'day'] = np.NaN
  elif len(release_date) == 7:
    merged_cleaned.loc[i,'year'] = temp[0]
    merged_cleaned.loc[i,'month'] = temp[1]
    merged_cleaned.loc[i,'day'] = np.NaN
  else:
    merged_cleaned.loc[i,'year'] = temp[0]
    merged_cleaned.loc[i,'month'] = temp[1]
    merged_cleaned.loc[i,'day'] = temp[2]
# Out:
# <ipython-input-119-66781714eb00>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_cleaned.loc[i,'year'] = temp[0]
# <ipython-input-119-66781714eb00>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_cleaned.loc[i,'month'] = temp[1]
# <ipython-input-119-66781714eb00>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_cleaned.loc[i,'day'] = temp[2]

# %%
merged_cleaned
# Out:
#                              track_name  Listeners  Playcount  popularity  \
# 0                     When I'm With You      41296     660264          74
# 1               Moonlit Floor (Kiss Me)     164108    2545493          79
# 2                                   Who     290397  118664117          86
# 3             New Woman (feat. ROSALÍA)      13329     573805          77
# 4                      Die With A Smile      35802     562233          97
# ...                                 ...        ...        ...         ...
# 7206  How To Save A Life - Techno Remix       3170      11974          55
# 7207                              裸足の季節       3947      27554          33
# 7208                   Light Up the Sky      68134     369364          43
# 7209                    Die Welt Brennt        250       1230          48
# 7210  Body Language - Original Remaster         63        201          42
#
#                          artist                              album  \
# 0                     NCT DREAM                         DREAMSCAPE
# 1                          LISA            Moonlit Floor (Kiss Me)
# 2                         Jimin                               MUSE
# 3                 LISA, ROSALÍA          New Woman (feat. ROSALÍA)
# 4         Lady Gaga, Bruno Mars                   Die With A Smile
# ...                         ...                                ...
# 7206                  Discotekk  How To Save A Life (Techno Remix)
# 7207              Seiko Matsuda                              BIBLE
# 7208                The Prodigy                        No Tourists
# 7209  Klangkuenstler, Obernauer                    Die Welt Brennt
# 7210    M.A.N.D.Y., Booka Shade                      Body Language
#
#      release_date        views      likes  year month  day
# 0      2024-11-11    1356990.0    76411.0  2024    11   11
# 1      2024-10-03   66200691.0  1310509.0  2024    10   03
# 2      2024-07-19   90380936.0  2662194.0  2024    07   19
# 3      2024-08-15  142792624.0  3299299.0  2024    08   15
# 4      2024-08-16  749845365.0  8793461.0  2024    08   16
# ...           ...          ...        ...   ...   ...  ...
# 7206   2023-09-15      63570.0      763.0  2023    09   15
# 7207         1980      43816.0      590.0  1980   NaN  NaN
# 7208   2018-11-02   12863259.0    88384.0  2018    11   02
# 7209   2023-02-03     293598.0     7622.0  2023    02   03
# 7210   2023-03-31      63870.0     1337.0  2023    03   31
#
# [7169 rows x 12 columns]

# %%
merged_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7169 entries, 0 to 7210
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_name    7169 non-null   object
#  1   Listeners     7169 non-null   int64
#  2   Playcount     7169 non-null   int64
#  3   popularity    7169 non-null   int64
#  4   artist        7169 non-null   object
#  5   album         7169 non-null   object
#  6   release_date  7169 non-null   object
#  7   views         7169 non-null   float64
#  8   likes         7169 non-null   float64
#  9   year          7169 non-null   object
#  10  month         6733 non-null   object
#  11  day           6714 non-null   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 986.1+ KB

# %%
merged_cleaned.to_csv('merged_data.csv', index=False)

# %%
merged_cleaned.columns
# Out:
# Index(['track_name', 'Listeners', 'Playcount', 'popularity', 'artist', 'album',
#        'release_date', 'views', 'likes', 'year', 'month', 'day'],
#       dtype='object')

# %% [markdown]
# # Finding Trend score using PCA

# %%
test_df = merged_cleaned.copy()

# %%
# !pip install requests

# %%
import requests as req
import pandas as pd

url = "http://10.48.104.39:8854/songs"
response = req.get(url)
data = response.json()

# Convert to DataFrame
df = pd.DataFrame(data['songs'])
df['artists'] = df['artists'].apply(lambda x: ', '.join(x))
df.sample(5)

# %%
test_df[test_df['artist'] == 'Billie Eilish, Khalid']
# Out:
#                track_name  Listeners  Playcount  popularity  \
# 115  lovely (with Khalid)      19684     116930          83
#
#                     artist                 album release_date         views  \
# 115  Billie Eilish, Khalid  lovely (with Khalid)   2018-04-19  2.172596e+09
#
#           likes  year month day  trend_score
# 115  27727950.0  2018    04  19       7.2675

# %%
test_df[test_df['track_name'] == 'Despacito']
# Out:
#      track_name  Listeners  Playcount  popularity                    artist  \
# 2540  Despacito       9721      45163          75  Luis Fonsi, Daddy Yankee
#
#      album release_date         views       likes  year month day  trend_score
# 2540  VIDA   2019-02-01  8.665842e+09  54509825.0  2019    02  01    18.567034

# %%
test_df[test_df['track_name'] == 'BIRDS OF A FEATHER']
# Out:
#            track_name  Listeners  Playcount  popularity         artist  \
# 5  BIRDS OF A FEATHER    1628334   36478173          94  Billie Eilish
#
#                   album release_date        views      likes  year month day  \
# 5  HIT ME HARD AND SOFT   2024-05-17  264438203.0  2949462.0  2024    05  17
#
#    trend_score
# 5     5.279737

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Assuming your data is in a DataFrame called 'df'
trend_cols = ['Listeners', 'Playcount', 'popularity', 'views', 'likes']

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(test_df[trend_cols])

# Apply PCA with n_components=1
pca = PCA(n_components=1)
pca.fit(scaled_data)

# Transform the data to the first principal component
trend_score = pca.transform(scaled_data)

# Add the trend score to the DataFrame
test_df['trend_score'] = trend_score

# Optional: Get the loadings (weights)
loadings = pca.components_[0]
print("Loadings (Weights):", loadings)
# Out:
# Loadings (Weights): [0.45959386 0.43411476 0.43967379 0.43969907 0.46224403]

# %%
# Now you can use 'df['trend_score']' to identify trending songs
# top_10_trending = test_df.nlargest(10, 'trend_score')
top_10_trending = test_df.nlargest(10, 'popularity')
top_10_trending[['track_name','year','popularity','trend_score']]
# Out:
#                           track_name  year  popularity  trend_score
# 4                   Die With A Smile  2024          97     3.033536
# 5                 BIRDS OF A FEATHER  2024          94     5.279737
# 472                      Not Like Us  2024          92     4.664820
# 22                        WILDFLOWER  2024          91     3.078633
# 21                  Good Luck, Babe!  2024          90     4.663186
# 60                       Sailor Song  2024          90     1.991023
# 473         All The Stars (with SZA)  2018          90     0.508337
# 59    Timeless (feat. Playboi Carti)  2024          88     0.507926
# 2542    Si Antes Te Hubiera Conocido  2024          88     1.839801
# 4318               DENIAL IS A RIVER  2024          88     1.786646
